# %% [markdown]
# ## Nonlinear Regression Hands-On

# %% [markdown]
# ### Load library

# %%
library("ggplot2")

# %% [markdown]
# ### Read in Data

# %%
nonlinear <- read.csv("/Users/kenyashiafernandez/Desktop/Data-Science-Program/DATASETS/nonlinear.csv")

# %%
head(nonlinear)
# Out:
#   X1    Y1     X2   Y2
# 1  9.55 183.13 1.74 65.01
# 2  7.98 204.44 0.13 13.55
# 3 13.42 121.54 0.20 16.58
# 4 13.40 111.86 0.76 22.87
# 5  7.67 206.74 0.78 22.01
# 6  5.97 205.72 1.65 53.96

# %% [markdown]
# ### Graph a Quadratic Relationship for First set

# %%
quadPlot <- ggplot(nonlinear, aes(x = X1, y= Y1)) + geom_point() + stat_smooth(method = "lm", formula = y ~x + I(x^2), size =1)
quadPlot
# Out:
# Warning message:
# “Removed 4 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 4 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ### Model the Quadratic Relationship

# %%
X1sq <- nonlinear$X1^2

# %%
quadModel <- lm(nonlinear$Y1~nonlinear$X1+X1sq)
summary(quadModel)
# Out:
# Call:
# lm(formula = nonlinear$Y1 ~ nonlinear$X1 + X1sq)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.1829 -3.5405  0.3129  3.3066  8.1229
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  134.0067    10.6525   12.58 6.26e-14 ***
# nonlinear$X1  22.4021     2.1788   10.28 1.14e-11 ***
# X1sq          -1.7723     0.1066  -16.62  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.338 on 32 degrees of freedom
#   (4 observations deleted due to missingness)
# Multiple R-squared:  0.9871,	Adjusted R-squared:  0.9863
# F-statistic:  1221 on 2 and 32 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Create an exponential function for the first set

# %% [markdown]
# ### Load in data

# %%
nonlinear <- read.csv("/Users/kenyashiafernandez/Desktop/Data-Science-Program/DATASETS/nonlinear.csv")

# %% [markdown]
# ### Exponential modeling

# %%
exMod <- lm(log(nonlinear$Y1)~nonlinear$X1)
summary(exMod)
# Out:
# Call:
# lm(formula = log(nonlinear$Y1) ~ nonlinear$X1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.26429 -0.02932  0.02343  0.07061  0.13519
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   6.005020   0.071561   83.92  < 2e-16 ***
# nonlinear$X1 -0.090368   0.007075  -12.77 2.54e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1058 on 33 degrees of freedom
#   (4 observations deleted due to missingness)
# Multiple R-squared:  0.8317,	Adjusted R-squared:  0.8266
# F-statistic: 163.1 on 1 and 33 DF,  p-value: 2.544e-14

# %% [markdown]
# ### Graph a Quadratic Relationship for second set

# %%
quadPlot1 <- ggplot(nonlinear, aes(x = X2, y= Y2)) + geom_point() + stat_smooth(method = "lm", formula = y ~x + I(x^2), size =1)
quadPlot1
# Out:
# plot without title

# %% [markdown]
# ### Model the Quadratic Relationship

# %%
X2sq1 <- nonlinear$X2^2

# %%
quadModel1 <- lm(nonlinear$Y2~nonlinear$X2+X2sq1)
summary(quadModel)
# Out:
# Call:
# lm(formula = nonlinear$Y1 ~ nonlinear$X1 + X1sq)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.1829 -3.5405  0.3129  3.3066  8.1229
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  134.0067    10.6525   12.58 6.26e-14 ***
# nonlinear$X1  22.4021     2.1788   10.28 1.14e-11 ***
# X1sq          -1.7723     0.1066  -16.62  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.338 on 32 degrees of freedom
#   (4 observations deleted due to missingness)
# Multiple R-squared:  0.9871,	Adjusted R-squared:  0.9863
# F-statistic:  1221 on 2 and 32 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Create an exponential function for the second set

# %%
exMod1 <- lm(log(nonlinear$Y2)~nonlinear$X2)
summary(exMod1)
# Out:
# Call:
# lm(formula = log(nonlinear$Y2) ~ nonlinear$X2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.43355 -0.07484  0.02495  0.09559  0.31863
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.29060    0.05693   40.23   <2e-16 ***
# nonlinear$X2  0.99481    0.05189   19.17   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1489 on 37 degrees of freedom
# Multiple R-squared:  0.9085,	Adjusted R-squared:  0.9061
# F-statistic: 367.6 on 1 and 37 DF,  p-value: < 2.2e-16
